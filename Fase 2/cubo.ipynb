# %%
# Definindo cada tipo de cubo
pintada_0 = 0
pintada_1 = 0
pintada_2 = 0
pintada_3 = 8

# Dimensão do cubo
n = int(input())
total = n ** 3

# Cálculo:
pintada_2 = (n - 2) * 2 * 6 # Cubinhos com 2 faces pintadas
pintada_1 = pintada_3/4 + pintada_2/6

# # # #  # # #  # #  #
# # # #  # # #  # #
# # # #  # # #
# # # #
# Out:
# 4
# 4 24
